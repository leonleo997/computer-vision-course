# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>

# %% [markdown]
# # Image Basics Assessment
#
# ## Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
# %config Completer.use_jedi = False

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

# %%
org_img=cv2.imread("../Computer-Vision-with-Python/DATA/dog_backpack.jpg")

# %%
plt.imshow(org_img)

# %%
fixed_img = cv2.cvtColor(org_img,cv2.COLOR_BGR2RGB)
plt.imshow(fixed_img)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
plt.imshow(cv2.flip(fixed_img, 0))

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %%
copy_img = fixed_img.copy()
plt.imshow(copy_img)

# %%
cv2.rectangle(copy_img,(180,350),(650,750),(255,0,0),5)
plt.imshow(copy_img)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
vertices=np.array([[450,400],[250,700],[600,700]])
vertices=vertices.reshape(3,-1,2)

# %%
vertices.shape

img2=fixed_img.copy()
(cv2.polylines(img2,[vertices],True, (0,0,255), 20))
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 49,  41,  38],
#         [ 51,  39,  39],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  80,  86],
#         [ 72,  77,  83],
#         [ 70,  75,  79]],
#
#        [[ 50,  42,  39],
#         [ 52,  40,  40],
#         [ 53,  37,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 51,  43,  40],
#         [ 51,  39,  39],
#         [ 54,  38,  39],
#         ...,
#         [ 76,  83,  89],
#         [ 71,  78,  84],
#         [ 67,  75,  78]]], dtype=uint8)

# %% [markdown]
# ### BONUS TASK. Can you figure our how to fill in this triangle? It requires a different function that we didn't show in the lecture! See if you can use google search to find it.
#
# [CLICK ME FOR A DIRECT LINK TO THE HINT](https://docs.opencv.org/3.0-beta/modules/imgproc/doc/drawing_functions.html#fillpoly)

# %%
plt.imshow(cv2.fillPoly(img2,[vertices], (0,0,255)))

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.

# %%
img3=org_img.copy()
#img3=cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)

def drawCircle(event,x,y,flags,params):
    if(event ==cv2.EVENT_LBUTTONDOWN):
        cv2.circle(img3,(x,y),50,(0,0,255), 8)
        
cv2.namedWindow("my_draw")
cv2.setMouseCallback("my_draw", drawCircle)


while True:
    cv2.imshow("my_draw", img3)
    if cv2.waitKey(20) & 0xFF==27:
        break
        
cv2.destroyAllWindows()
